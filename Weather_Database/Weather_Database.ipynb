# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name 
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
    
    
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | baruun-urt
# Processing Record 2 of Set 1 | beringovskiy
# Processing Record 3 of Set 1 | illela
# Processing Record 4 of Set 1 | meulaboh
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | andselv
# City not found. Skipping...
# Processing Record 8 of Set 1 | santa maria
# Processing Record 9 of Set 1 | ayan
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | djibo
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | san quintin
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | alamos
# Processing Record 18 of Set 1 | puerto escondido
# Processing Record 19 of Set 1 | derzhavinsk
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | samarai
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | luau
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | ahipara
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | gympie
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 33 of Set 1 | kulhudhuffushi
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | florianopolis
# Processing Record 36 of Set 1 | mezen
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | airai
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | malakal
# Processing Record 41 of Set 1 | noumea
# Processing Record 42 of Set 1 | port lincoln
# Processing Record 43 of Set 1 | majene
# Processing Record 44 of Set 1 | binalan
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 1 | kigorobya
# Processing Record 48 of Set 1 | westport
# Processing Record 49 of Set 1 | nalut
# Processing Record 50 of Set 1 | kaeo
# Processing Record 1 of Set 2 | batagay
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | vardo
# Processing Record 4 of Set 2 | umm lajj
# Processing Record 5 of Set 2 | abu kamal
# Processing Record 6 of Set 2 | benguela
# Processing Record 7 of Set 2 | barroualie
# City not found. Skipping...
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | kargopol
# Processing Record 10 of Set 2 | khani
# Processing Record 11 of Set 2 | tomatlan
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | mehamn
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | hofn
# Processing Record 17 of Set 2 | teya
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | sivas
# Processing Record 20 of Set 2 | fort nelson
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | killeen
# Processing Record 23 of Set 2 | guerrero negro
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | santa cruz cabralia
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | kaitangata
# Processing Record 30 of Set 2 | ejido hermosillo
# Processing Record 31 of Set 2 | mitsamiouli
# Processing Record 32 of Set 2 | andra
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | broken hill
# Processing Record 35 of Set 2 | aitape
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | oussouye
# Processing Record 39 of Set 2 | pinega
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | kasongo-lunda
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | zarand
# Processing Record 45 of Set 2 | santa cecilia
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | brookings
# Processing Record 50 of Set 2 | busselton
# Processing Record 1 of Set 3 | luwuk
# Processing Record 2 of Set 3 | xining
# Processing Record 3 of Set 3 | svetlogorsk
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | biak
# Processing Record 7 of Set 3 | floro
# Processing Record 8 of Set 3 | adrar
# Processing Record 9 of Set 3 | yanam
# Processing Record 10 of Set 3 | bahia de caraquez
# Processing Record 11 of Set 3 | tuy hoa
# Processing Record 12 of Set 3 | ketchikan
# Processing Record 13 of Set 3 | paldiski
# Processing Record 14 of Set 3 | dingle
# Processing Record 15 of Set 3 | shelby
# Processing Record 16 of Set 3 | kjopsvik
# Processing Record 17 of Set 3 | norman wells
# Processing Record 18 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 3 | troitskoye
# Processing Record 20 of Set 3 | fortuna
# Processing Record 21 of Set 3 | mandali
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | polonnaruwa
# Processing Record 24 of Set 3 | esperance
# Processing Record 25 of Set 3 | crib point
# Processing Record 26 of Set 3 | port hedland
# Processing Record 27 of Set 3 | kholmogory
# Processing Record 28 of Set 3 | padre bernardo
# Processing Record 29 of Set 3 | arman
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | nemuro
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | gat
# Processing Record 34 of Set 3 | walvis bay
# Processing Record 35 of Set 3 | sept-iles
# Processing Record 36 of Set 3 | medea
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | oksfjord
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | manokwari
# Processing Record 42 of Set 3 | broome
# Processing Record 43 of Set 3 | morondava
# Processing Record 44 of Set 3 | disraeli
# Processing Record 45 of Set 3 | kovdor
# Processing Record 46 of Set 3 | hokitika
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 3 | benghazi
# Processing Record 1 of Set 4 | manta
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | kavieng
# Processing Record 4 of Set 4 | houma
# Processing Record 5 of Set 4 | namatanai
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | yar-sale
# Processing Record 8 of Set 4 | margate
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | la ronge
# Processing Record 12 of Set 4 | codrington
# Processing Record 13 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | sioux lookout
# Processing Record 16 of Set 4 | peranamallur
# Processing Record 17 of Set 4 | pauini
# Processing Record 18 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 4 | narsaq
# Processing Record 20 of Set 4 | seinajoki
# Processing Record 21 of Set 4 | souillac
# Processing Record 22 of Set 4 | sitka
# Processing Record 23 of Set 4 | nanortalik
# Processing Record 24 of Set 4 | lichuan
# Processing Record 25 of Set 4 | thunder bay
# Processing Record 26 of Set 4 | saint-philippe
# Processing Record 27 of Set 4 | okha
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | bayshore gardens
# Processing Record 30 of Set 4 | xingtai
# Processing Record 31 of Set 4 | prince rupert
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | marfino
# Processing Record 34 of Set 4 | necochea
# Processing Record 35 of Set 4 | jiuquan
# Processing Record 36 of Set 4 | kroya
# Processing Record 37 of Set 4 | emirdag
# Processing Record 38 of Set 4 | tumbotino
# Processing Record 39 of Set 4 | moses lake
# Processing Record 40 of Set 4 | lahij
# Processing Record 41 of Set 4 | sobolevo
# Processing Record 42 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 4 | awbari
# Processing Record 44 of Set 4 | semirom
# Processing Record 45 of Set 4 | san lorenzo
# Processing Record 46 of Set 4 | tessalit
# Processing Record 47 of Set 4 | luan
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | matagami
# Processing Record 50 of Set 4 | cape coast
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | provideniya
# Processing Record 3 of Set 5 | waddan
# Processing Record 4 of Set 5 | lebu
# Processing Record 5 of Set 5 | lleida
# Processing Record 6 of Set 5 | puerto gaitan
# Processing Record 7 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 5 | baie-comeau
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | lorengau
# Processing Record 11 of Set 5 | naze
# Processing Record 12 of Set 5 | grindavik
# Processing Record 13 of Set 5 | narkanda
# Processing Record 14 of Set 5 | kristiansund
# Processing Record 15 of Set 5 | nantucket
# Processing Record 16 of Set 5 | morro bay
# Processing Record 17 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 5 | hualmay
# Processing Record 19 of Set 5 | thinadhoo
# Processing Record 20 of Set 5 | yerbogachen
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | tamala
# Processing Record 24 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 5 | chillicothe
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | newport
# Processing Record 28 of Set 5 | pirajui
# Processing Record 29 of Set 5 | talnakh
# Processing Record 30 of Set 5 | cascais
# Processing Record 31 of Set 5 | cayenne
# Processing Record 32 of Set 5 | nome
# Processing Record 33 of Set 5 | hongjiang
# Processing Record 34 of Set 5 | kavaratti
# Processing Record 35 of Set 5 | lagoa
# Processing Record 36 of Set 5 | ulverstone
# Processing Record 37 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 38 of Set 5 | valdivia
# Processing Record 39 of Set 5 | mitchell
# Processing Record 40 of Set 5 | yong peng
# Processing Record 41 of Set 5 | athabasca
# Processing Record 42 of Set 5 | nizwa
# Processing Record 43 of Set 5 | udachnyy
# Processing Record 44 of Set 5 | kapit
# Processing Record 45 of Set 5 | cap malheureux
# Processing Record 46 of Set 5 | kota kinabalu
# Processing Record 47 of Set 5 | tabuk
# Processing Record 48 of Set 5 | mahebourg
# Processing Record 49 of Set 5 | presidente medici
# Processing Record 50 of Set 5 | placido de castro
# Processing Record 1 of Set 6 | yarim
# Processing Record 2 of Set 6 | aguimes
# Processing Record 3 of Set 6 | band
# Processing Record 4 of Set 6 | kologriv
# Processing Record 5 of Set 6 | nador
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | tanete
# Processing Record 8 of Set 6 | uyovu
# Processing Record 9 of Set 6 | zarubino
# Processing Record 10 of Set 6 | beroroha
# Processing Record 11 of Set 6 | lingao
# Processing Record 12 of Set 6 | upernavik
# Processing Record 13 of Set 6 | pilar
# Processing Record 14 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 6 | grand gaube
# Processing Record 16 of Set 6 | comodoro rivadavia
# Processing Record 17 of Set 6 | aswan
# Processing Record 18 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 6 | chokurdakh
# Processing Record 20 of Set 6 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 21 of Set 6 | merauke
# Processing Record 22 of Set 6 | oxford
# Processing Record 23 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 6 | clyde river
# Processing Record 25 of Set 6 | isangel
# Processing Record 26 of Set 6 | kieta
# Processing Record 27 of Set 6 | lodja
# Processing Record 28 of Set 6 | katsuura
# Processing Record 29 of Set 6 | taoudenni
# Processing Record 30 of Set 6 | general pico
# Processing Record 31 of Set 6 | christchurch
# Processing Record 32 of Set 6 | sa kaeo
# Processing Record 33 of Set 6 | pitimbu
# Processing Record 34 of Set 6 | vagur
# Processing Record 35 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 6 | ulladulla
# Processing Record 37 of Set 6 | bajil
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | bagan
# Processing Record 40 of Set 6 | shimanovsk
# Processing Record 41 of Set 6 | vestmannaeyjar
# Processing Record 42 of Set 6 | husavik
# Processing Record 43 of Set 6 | meadow lake
# Processing Record 44 of Set 6 | palu
# Processing Record 45 of Set 6 | balkhash
# Processing Record 46 of Set 6 | chuy
# Processing Record 47 of Set 6 | sinjar
# Processing Record 48 of Set 6 | xichang
# Processing Record 49 of Set 6 | ancud
# Processing Record 50 of Set 6 | akcakoca
# Processing Record 1 of Set 7 | korla
# Processing Record 2 of Set 7 | usinsk
# Processing Record 3 of Set 7 | divo
# Processing Record 4 of Set 7 | abnub
# Processing Record 5 of Set 7 | coihaique
# Processing Record 6 of Set 7 | alice town
# Processing Record 7 of Set 7 | ostrovnoy
# Processing Record 8 of Set 7 | norrtalje
# Processing Record 9 of Set 7 | kharabali
# Processing Record 10 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 7 | goundam
# Processing Record 12 of Set 7 | demyansk
# Processing Record 13 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 7 | maragogi
# Processing Record 15 of Set 7 | tambun
# Processing Record 16 of Set 7 | leeton
# Processing Record 17 of Set 7 | moron
# Processing Record 18 of Set 7 | kenora
# Processing Record 19 of Set 7 | houston
# Processing Record 20 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 21 of Set 7 | am timan
# Processing Record 22 of Set 7 | setermoen
# Processing Record 23 of Set 7 | inhambane
# Processing Record 24 of Set 7 | wahiawa
# Processing Record 25 of Set 7 | male
# Processing Record 26 of Set 7 | marawi
# Processing Record 27 of Set 7 | torbay
# Processing Record 28 of Set 7 | chifeng
# Processing Record 29 of Set 7 | san andres
# Processing Record 30 of Set 7 | dudinka
# Processing Record 31 of Set 7 | cherskiy
# Processing Record 32 of Set 7 | shalinskoye
# Processing Record 33 of Set 7 | djenne
# Processing Record 34 of Set 7 | nara
# Processing Record 35 of Set 7 | esso
# Processing Record 36 of Set 7 | padang
# Processing Record 37 of Set 7 | la baule-escoublac
# Processing Record 38 of Set 7 | acapulco
# Processing Record 39 of Set 7 | kodiak
# Processing Record 40 of Set 7 | san borja
# Processing Record 41 of Set 7 | port-gentil
# Processing Record 42 of Set 7 | aklavik
# Processing Record 43 of Set 7 | del rio
# Processing Record 44 of Set 7 | shirochanka
# Processing Record 45 of Set 7 | point fortin
# Processing Record 46 of Set 7 | manado
# Processing Record 47 of Set 7 | kilindoni
# Processing Record 48 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 7 | bac lieu
# Processing Record 50 of Set 7 | duiven
# Processing Record 1 of Set 8 | richards bay
# Processing Record 2 of Set 8 | north marysville
# City not found. Skipping...
# Processing Record 3 of Set 8 | seymour
# Processing Record 4 of Set 8 | chapais
# Processing Record 5 of Set 8 | le vauclin
# Processing Record 6 of Set 8 | sambava
# Processing Record 7 of Set 8 | senanga
# Processing Record 8 of Set 8 | tual
# Processing Record 9 of Set 8 | haines junction
# Processing Record 10 of Set 8 | bogorodsk
# Processing Record 11 of Set 8 | vostok
# Processing Record 12 of Set 8 | pyapon
# Processing Record 13 of Set 8 | bubaque
# Processing Record 14 of Set 8 | taua
# Processing Record 15 of Set 8 | iralaya
# Processing Record 16 of Set 8 | brae
# Processing Record 17 of Set 8 | chulman
# Processing Record 18 of Set 8 | kizema
# Processing Record 19 of Set 8 | vila franca do campo
# Processing Record 20 of Set 8 | hirara
# Processing Record 21 of Set 8 | puerto ayora
# Processing Record 22 of Set 8 | tolon
# Processing Record 23 of Set 8 | khorixas
# Processing Record 24 of Set 8 | bone
# Processing Record 25 of Set 8 | the pas
# Processing Record 26 of Set 8 | kruisfontein
# Processing Record 27 of Set 8 | nkan
# Processing Record 28 of Set 8 | uhlove
# Processing Record 29 of Set 8 | borgustanskaya
# Processing Record 30 of Set 8 | alugan
# Processing Record 31 of Set 8 | port blair
# Processing Record 32 of Set 8 | antsohihy
# Processing Record 33 of Set 8 | yumen
# Processing Record 34 of Set 8 | evensk
# Processing Record 35 of Set 8 | port hardy
# Processing Record 36 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 8 | borogontsy
# Processing Record 38 of Set 8 | homer
# Processing Record 39 of Set 8 | labuhan
# Processing Record 40 of Set 8 | la rioja
# Processing Record 41 of Set 8 | sungaipenuh
# Processing Record 42 of Set 8 | gongzhuling
# Processing Record 43 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 8 | yarada
# Processing Record 45 of Set 8 | pochutla
# Processing Record 46 of Set 8 | tiznit
# Processing Record 47 of Set 8 | kununurra
# Processing Record 48 of Set 8 | grootfontein
# Processing Record 49 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | edd
# Processing Record 2 of Set 9 | bandarbeyla
# Processing Record 3 of Set 9 | novytsya
# Processing Record 4 of Set 9 | angoram
# Processing Record 5 of Set 9 | markova
# Processing Record 6 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 9 | oriximina
# Processing Record 8 of Set 9 | the valley
# Processing Record 9 of Set 9 | omsukchan
# Processing Record 10 of Set 9 | snasa
# Processing Record 11 of Set 9 | leh
# Processing Record 12 of Set 9 | faya
# Processing Record 13 of Set 9 | adre
# Processing Record 14 of Set 9 | lake charles
# Processing Record 15 of Set 9 | magdalena
# Processing Record 16 of Set 9 | batang berjuntai
# Processing Record 17 of Set 9 | bathsheba
# Processing Record 18 of Set 9 | volodarskiy
# Processing Record 19 of Set 9 | anchorage
# Processing Record 20 of Set 9 | qostanay
# Processing Record 21 of Set 9 | zaragoza
# Processing Record 22 of Set 9 | fasa
# Processing Record 23 of Set 9 | laguna
# Processing Record 24 of Set 9 | poltavka
# Processing Record 25 of Set 9 | los algarrobos
# Processing Record 26 of Set 9 | rocha
# Processing Record 27 of Set 9 | pisco
# Processing Record 28 of Set 9 | atar
# Processing Record 29 of Set 9 | hambantota
# Processing Record 30 of Set 9 | general roca
# Processing Record 31 of Set 9 | novobiryusinskiy
# Processing Record 32 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 9 | okhotsk
# Processing Record 34 of Set 9 | karlstad
# Processing Record 35 of Set 9 | marinette
# Processing Record 36 of Set 9 | arvika
# Processing Record 37 of Set 9 | rongai
# Processing Record 38 of Set 9 | nagua
# Processing Record 39 of Set 9 | muros
# Processing Record 40 of Set 9 | kirakira
# Processing Record 41 of Set 9 | jalu
# Processing Record 42 of Set 9 | praya
# Processing Record 43 of Set 9 | xalpatlahuac
# Processing Record 44 of Set 9 | woodward
# Processing Record 45 of Set 9 | miri
# Processing Record 46 of Set 9 | banda aceh
# Processing Record 47 of Set 9 | reisterstown
# Processing Record 48 of Set 9 | saint-augustin
# Processing Record 49 of Set 9 | kaithal
# Processing Record 50 of Set 9 | toamasina
# Processing Record 1 of Set 10 | malacacheta
# Processing Record 2 of Set 10 | anjangaon
# Processing Record 3 of Set 10 | hulan
# Processing Record 4 of Set 10 | onega
# Processing Record 5 of Set 10 | nioro
# Processing Record 6 of Set 10 | rawson
# Processing Record 7 of Set 10 | yulara
# Processing Record 8 of Set 10 | tagusao
# Processing Record 9 of Set 10 | fukue
# Processing Record 10 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 11 of Set 10 | saint george
# Processing Record 12 of Set 10 | avera
# Processing Record 13 of Set 10 | anadyr
# Processing Record 14 of Set 10 | diamantino
# Processing Record 15 of Set 10 | gizycko
# Processing Record 16 of Set 10 | payo
# Processing Record 17 of Set 10 | pacific grove
# Processing Record 18 of Set 10 | ukiah
# Processing Record 19 of Set 10 | itarema
# Processing Record 20 of Set 10 | mazyr
# Processing Record 21 of Set 10 | kendari
# Processing Record 22 of Set 10 | constitucion
# Processing Record 23 of Set 10 | west wendover
# Processing Record 24 of Set 10 | kangaatsiaq
# Processing Record 25 of Set 10 | natal
# Processing Record 26 of Set 10 | kirkwood
# Processing Record 27 of Set 10 | safaga
# Processing Record 28 of Set 10 | yuty
# Processing Record 29 of Set 10 | ushibuka
# Processing Record 30 of Set 10 | namibe
# Processing Record 31 of Set 10 | maanshan
# Processing Record 32 of Set 10 | naron
# Processing Record 33 of Set 10 | dwarka
# Processing Record 34 of Set 10 | russell
# Processing Record 35 of Set 10 | tautira
# Processing Record 36 of Set 10 | agirish
# Processing Record 37 of Set 10 | klaksvik
# Processing Record 38 of Set 10 | warrnambool
# Processing Record 39 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 40 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 41 of Set 10 | presidencia roque saenz pena
# Processing Record 42 of Set 10 | san pedro
# Processing Record 43 of Set 10 | north platte
# Processing Record 44 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 10 | fairbanks
# Processing Record 46 of Set 10 | kingman
# Processing Record 47 of Set 10 | evansville
# Processing Record 48 of Set 10 | lompoc
# Processing Record 49 of Set 10 | hanmer springs
# Processing Record 50 of Set 10 | inta
# Processing Record 1 of Set 11 | tilichiki
# Processing Record 2 of Set 11 | kinablangan
# Processing Record 3 of Set 11 | panjab
# Processing Record 4 of Set 11 | pangnirtung
# Processing Record 5 of Set 11 | berlevag
# Processing Record 6 of Set 11 | mogadishu
# Processing Record 7 of Set 11 | sorland
# Processing Record 8 of Set 11 | sivaganga
# Processing Record 9 of Set 11 | kahului
# Processing Record 10 of Set 11 | khoy
# Processing Record 11 of Set 11 | tubuala
# Processing Record 12 of Set 11 | acajete
# Processing Record 13 of Set 11 | mercedes
# Processing Record 14 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 11 | kaifeng
# Processing Record 16 of Set 11 | talcahuano
# Processing Record 17 of Set 11 | pirgos
# Processing Record 18 of Set 11 | roald
# Processing Record 19 of Set 11 | chunoyar
# Processing Record 20 of Set 11 | peniche
# Processing Record 21 of Set 11 | abha
# Processing Record 22 of Set 11 | honiara
# Processing Record 23 of Set 11 | cidreira
# Processing Record 24 of Set 11 | belyy yar
# Processing Record 25 of Set 11 | muroto
# Processing Record 26 of Set 11 | pacifica
# Processing Record 27 of Set 11 | uralets
# Processing Record 28 of Set 11 | poum
# Processing Record 29 of Set 11 | salalah
# Processing Record 30 of Set 11 | bethel
# Processing Record 31 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 11 | fort-shevchenko
# Processing Record 33 of Set 11 | bulgan
# Processing Record 34 of Set 11 | ugoofaaru
# Processing Record 35 of Set 11 | caravelas
# Processing Record 36 of Set 11 | udalguri
# Processing Record 37 of Set 11 | dauphin
# Processing Record 38 of Set 11 | pontarlier
# Processing Record 39 of Set 11 | imbituba
# Processing Record 40 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 11 | bilma
# Processing Record 42 of Set 11 | mbandaka
# Processing Record 43 of Set 11 | uttaradit
# Processing Record 44 of Set 11 | xushan
# Processing Record 45 of Set 11 | college
# Processing Record 46 of Set 11 | timizart
# Processing Record 47 of Set 11 | mount gambier
# Processing Record 48 of Set 11 | moussoro
# Processing Record 49 of Set 11 | ossora
# Processing Record 50 of Set 11 | tongliao
# Processing Record 1 of Set 12 | port keats
# Processing Record 2 of Set 12 | okakarara
# Processing Record 3 of Set 12 | reconquista
# Processing Record 4 of Set 12 | rio grande
# Processing Record 5 of Set 12 | parauna
# Processing Record 6 of Set 12 | arrecife
# Processing Record 7 of Set 12 | atambua
# Processing Record 8 of Set 12 | tariba
# Processing Record 9 of Set 12 | gijon
# Processing Record 10 of Set 12 | mount isa
# Processing Record 11 of Set 12 | anloga
# Processing Record 12 of Set 12 | isla mujeres
# Processing Record 13 of Set 12 | te anau
# Processing Record 14 of Set 12 | liberal
# Processing Record 15 of Set 12 | arkhipo-osipovka
# Processing Record 16 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 17 of Set 12 | sri aman
# Processing Record 18 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 19 of Set 12 | chicama
# Processing Record 20 of Set 12 | rapu-rapu
# Processing Record 21 of Set 12 | tres arroyos
# Processing Record 22 of Set 12 | cartagena
# Processing Record 23 of Set 12 | yarmouth
# Processing Record 24 of Set 12 | lakes entrance
# Processing Record 25 of Set 12 | sorong
# Processing Record 26 of Set 12 | touros
# Processing Record 27 of Set 12 | camocim
# Processing Record 28 of Set 12 | joshimath
# Processing Record 29 of Set 12 | alice springs
# Processing Record 30 of Set 12 | auburn
# Processing Record 31 of Set 12 | black river
# Processing Record 32 of Set 12 | buchanan
# Processing Record 33 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 34 of Set 12 | gubkinskiy
# Processing Record 35 of Set 12 | preobrazheniye
# Processing Record 36 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 12 | srednekolymsk
# Processing Record 38 of Set 12 | sao joao da barra
# Processing Record 39 of Set 12 | lithgow
# Processing Record 40 of Set 12 | mamallapuram
# Processing Record 41 of Set 12 | hornepayne
# Processing Record 42 of Set 12 | flin flon
# Processing Record 43 of Set 12 | bati
# Processing Record 44 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 12 | hobyo
# Processing Record 46 of Set 12 | auki
# Processing Record 47 of Set 12 | peterhead
# Processing Record 48 of Set 12 | sangar
# Processing Record 49 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 12 | yinchuan
# Processing Record 1 of Set 13 | longfeng
# Processing Record 2 of Set 13 | zadar
# Processing Record 3 of Set 13 | yahotyn
# Processing Record 4 of Set 13 | zhigansk
# Processing Record 5 of Set 13 | pangkalanbuun
# Processing Record 6 of Set 13 | trojes
# Processing Record 7 of Set 13 | asau
# Processing Record 8 of Set 13 | toledo
# Processing Record 9 of Set 13 | manali
# Processing Record 10 of Set 13 | gamba
# Processing Record 11 of Set 13 | addanki
# Processing Record 12 of Set 13 | zhezkazgan
# Processing Record 13 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 13 | uige
# Processing Record 15 of Set 13 | sekoma
# Processing Record 16 of Set 13 | ndjole
# Processing Record 17 of Set 13 | malappuram
# Processing Record 18 of Set 13 | mazagao
# Processing Record 19 of Set 13 | vila velha
# Processing Record 20 of Set 13 | high prairie
# Processing Record 21 of Set 13 | antofagasta
# Processing Record 22 of Set 13 | nukus
# Processing Record 23 of Set 13 | haimen
# Processing Record 24 of Set 13 | santa vitoria do palmar
# Processing Record 25 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 26 of Set 13 | jian
# Processing Record 27 of Set 13 | cabinda
# Processing Record 28 of Set 13 | sembe
# Processing Record 29 of Set 13 | plaster rock
# Processing Record 30 of Set 13 | sisimiut
# Processing Record 31 of Set 13 | dicabisagan
# Processing Record 32 of Set 13 | cervo
# Processing Record 33 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 34 of Set 13 | acajutla
# Processing Record 35 of Set 13 | ulagan
# Processing Record 36 of Set 13 | sinnamary
# Processing Record 37 of Set 13 | guilin
# Processing Record 38 of Set 13 | predivinsk
# Processing Record 39 of Set 13 | bud
# Processing Record 40 of Set 13 | bilibino
# Processing Record 41 of Set 13 | olinda
# Processing Record 42 of Set 13 | shahr-e kord
# Processing Record 43 of Set 13 | ternate
# Processing Record 44 of Set 13 | lat yao
# Processing Record 45 of Set 13 | kampot
# Processing Record 46 of Set 13 | grand junction
# Processing Record 47 of Set 13 | bacolod
# Processing Record 48 of Set 13 | tocopilla
# Processing Record 49 of Set 13 | poya
# Processing Record 50 of Set 13 | guaruja
# Processing Record 1 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 14 | kalemie
# Processing Record 3 of Set 14 | hudson bay
# Processing Record 4 of Set 14 | alpena
# Processing Record 5 of Set 14 | aojiang
# Processing Record 6 of Set 14 | aranda de duero
# Processing Record 7 of Set 14 | mayumba
# Processing Record 8 of Set 14 | ilulissat
# Processing Record 9 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 14 | yermolayevo
# Processing Record 11 of Set 14 | barcelona
# Processing Record 12 of Set 14 | greenwood
# Processing Record 13 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 14 | kita
# Processing Record 15 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 14 | koroni
# Processing Record 17 of Set 14 | tyukhtet
# Processing Record 18 of Set 14 | neuquen
# Processing Record 19 of Set 14 | quartucciu
# Processing Record 20 of Set 14 | ranong
# Processing Record 21 of Set 14 | rokupr
# Processing Record 22 of Set 14 | san juan
# Processing Record 23 of Set 14 | morros
# Processing Record 24 of Set 14 | nizhnyaya omka
# Processing Record 25 of Set 14 | black forest
# Processing Record 26 of Set 14 | half moon bay
# Processing Record 27 of Set 14 | progreso
# Processing Record 28 of Set 14 | pahrump
# Processing Record 29 of Set 14 | murakeresztur
# Processing Record 30 of Set 14 | belokurikha
# Processing Record 31 of Set 14 | seoul
# Processing Record 32 of Set 14 | morgan city
# Processing Record 33 of Set 14 | pandrup
# Processing Record 34 of Set 14 | bouar
# Processing Record 35 of Set 14 | awjilah
# Processing Record 36 of Set 14 | tuensang
# Processing Record 37 of Set 14 | torit
# Processing Record 38 of Set 14 | moba
# Processing Record 39 of Set 14 | kloulklubed
# Processing Record 40 of Set 14 | taltal
# Processing Record 41 of Set 14 | springbok
# Processing Record 42 of Set 14 | jinchang
# Processing Record 43 of Set 14 | kikwit
# Processing Record 44 of Set 14 | san ramon de la nueva oran
# Processing Record 45 of Set 14 | beaverlodge
# Processing Record 46 of Set 14 | rumonge
# Processing Record 47 of Set 14 | kupang
# Processing Record 48 of Set 14 | nelson bay
# Processing Record 49 of Set 14 | tabou
# Processing Record 50 of Set 14 | diapaga
# Processing Record 1 of Set 15 | maceio
# Processing Record 2 of Set 15 | dukat
# Processing Record 3 of Set 15 | platon sanchez
# Processing Record 4 of Set 15 | ringe
# Processing Record 5 of Set 15 | essex
# Processing Record 6 of Set 15 | baldeogarh
# Processing Record 7 of Set 15 | san vicente
# Processing Record 8 of Set 15 | eydhafushi
# Processing Record 9 of Set 15 | aasiaat
# Processing Record 10 of Set 15 | zhireken
# Processing Record 11 of Set 15 | riyadh
# Processing Record 12 of Set 15 | san rafael
# Processing Record 13 of Set 15 | nazret
# Processing Record 14 of Set 15 | maniitsoq
# Processing Record 15 of Set 15 | ambilobe
# Processing Record 16 of Set 15 | kissidougou
# Processing Record 17 of Set 15 | krasnoselkup
# Processing Record 18 of Set 15 | sibolga
# Processing Record 19 of Set 15 | geraldton
# Processing Record 20 of Set 15 | mocuba
# Processing Record 21 of Set 15 | lekoni
# Processing Record 22 of Set 15 | asfi
# Processing Record 23 of Set 15 | vao
# Processing Record 24 of Set 15 | tezu
# Processing Record 25 of Set 15 | lanskroun
# Processing Record 26 of Set 15 | puerto baquerizo moreno
# Processing Record 27 of Set 15 | paamiut
# Processing Record 28 of Set 15 | calama
# Processing Record 29 of Set 15 | lata
# Processing Record 30 of Set 15 | vila
# Processing Record 31 of Set 15 | soyo
# Processing Record 32 of Set 15 | port hueneme
# Processing Record 33 of Set 15 | sohag
# Processing Record 34 of Set 15 | katakwi
# Processing Record 35 of Set 15 | northam
# Processing Record 36 of Set 15 | pakokku
# Processing Record 37 of Set 15 | yaan
# Processing Record 38 of Set 15 | boende
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 685

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Baruun-Urt  46.6806  113.2792     62.08        26          40
# 1  Beringovskiy  63.0500  179.3167     31.71        83          99
# 2        Illela  13.7292    5.2975     94.30        36          31
# 3      Meulaboh   4.1363   96.1285     73.36        95         100
# 4      Hermanus -34.4187   19.2345     66.79        68          39
# 5     Carnarvon -24.8667  113.6333     69.75        63           0
# 6   Santa Maria -29.6842  -53.8069     61.90        63          75
# 7          Ayan  56.4500  138.1667     39.02        58         100
# 8  Punta Arenas -53.1500  -70.9167     53.71        40           0
# 9         Djibo  14.1022   -1.6306     95.74        34          72
#
#    Wind Speed Country Current Description
# 0       15.64      MN    scattered clouds
# 1       14.67      RU     overcast clouds
# 2        7.94      NG    scattered clouds
# 3        2.55      ID          light rain
# 4        7.56      ZA    scattered clouds
# 5       20.29      AU           clear sky
# 6       13.80      BR       broken clouds
# 7       19.93      RU     overcast clouds
# 8       12.66      CL           clear sky
# 9       10.71      BF       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
new_city_data_df = city_data_df[new_column_order]

# Display sample data
new_city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Baruun-Urt      MN  46.6806  113.2792     62.08        26          40
# 1  Beringovskiy      RU  63.0500  179.3167     31.71        83          99
# 2        Illela      NG  13.7292    5.2975     94.30        36          31
# 3      Meulaboh      ID   4.1363   96.1285     73.36        95         100
# 4      Hermanus      ZA -34.4187   19.2345     66.79        68          39
#
#    Wind Speed Current Description
# 0       15.64    scattered clouds
# 1       14.67     overcast clouds
# 2        7.94    scattered clouds
# 3        2.55          light rain
# 4        7.56    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
new_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
